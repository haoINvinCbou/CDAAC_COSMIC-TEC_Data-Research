# %%
from netCDF4 import Dataset
import numpy as np
import math as Math
import matplotlib as mplt
import matplotlib.pyplot as plt


#解决plot画图无法显示中文的问题
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei'] # 指定默认字体  
mpl.rcParams['axes.unicode_minus'] = False # 解决保存图像是负号'-'显示为方块的问题  

a = 6378137;
f = 0.0034;
b = 6.3568e6;
e = Math.sqrt((Math.pow(a, 2) - Math.pow(b, 2)) / Math.pow(a, 2));
e2 = Math.sqrt((Math.pow(a, 2) - Math.pow(b, 2)) / Math.pow(b, 2));

# %%
def ecf2lla(x, y, z) :

    np.set_printoptions(suppress=True) 
    x = x*1000
    y = y*1000
    z = z*1000
    
    p = Math.sqrt(Math.pow(x, 2) + Math.pow(y, 2));

    theta = Math.atan((z * a) / (p * b));

    lon = Math.atan(y / x);

    lat = Math.atan(((z + Math.pow(e2, 2) * b * Math.pow(Math.sin(theta), 3)) / ((p - Math.pow(e, 2) * a * Math.pow(Math.cos(theta), 3)))));
    
    N = a / (Math.sqrt(1 - (Math.pow(e, 2) * Math.pow(Math.sin(lat), 2))));

    m = (p / Math.cos(lat));
    
    height = m - N;


    lon = lon * 180 / Math.pi;
    lat = lat * 180 / Math.pi; 
    
    return lat,lon,height

# %%
namec1 = ["G17\podTec_C001.2011.091.00.22.0028.G17.01_2013.nc",
"G17\podTec_C001.2011.091.02.06.0030.G17.01_2013.nc",
"G17\podTec_C001.2011.091.04.34.0022.G17.01_2013.nc",
"G17\podTec_C001.2011.091.06.15.0029.G17.01_2013.nc",
"G17\podTec_C001.2011.091.07.58.0031.G17.01_2013.nc",
"G17\podTec_C001.2011.091.10.29.0025.G17.01_2013.nc",
"G17\podTec_C001.2011.091.12.08.0028.G17.01_2013.nc",
"G17\podTec_C001.2011.091.13.52.0030.G17.01_2013.nc",
"G17\podTec_C001.2011.091.16.20.0018.G17.01_2013.nc",
"G17\podTec_C001.2011.091.18.01.0028.G17.01_2013.nc",
"G17\podTec_C001.2011.091.19.46.0029.G17.01_2013.nc",
"G17\podTec_C001.2011.091.22.19.0021.G17.01_2013.nc",
"G17\podTec_C001.2011.091.23.55.0027.G17.01_2013.nc"]

namec2 = ["G17\podTec_C002.2011.091.00.31.0027.G17.01_2013.nc",
"G17\podTec_C002.2011.091.04.26.0029.G17.01_2013.nc",
"G17\podTec_C002.2011.091.05.44.0036.G17.00_2013.nc",
"G17\podTec_C002.2011.091.06.22.0028.G17.01_2013.nc",
"G17\podTec_C002.2011.091.08.12.0033.G17.01_2013.nc",
"G17\podTec_C002.2011.091.12.16.0027.G17.01_2013.nc",
"G17\podTec_C002.2011.091.13.31.0028.G17.00_2013.nc",
"G17\podTec_C002.2011.091.14.08.0030.G17.01_2013.nc",
"G17\podTec_C002.2011.091.16.07.0032.G17.01_2013.nc",
"G17\podTec_C002.2011.091.17.28.0026.G17.00_2013.nc",
"G17\podTec_C002.2011.091.18.06.0024.G17.01_2013.nc",
"G17\podTec_C002.2011.091.21.59.0033.G17.01_2013.nc",
"G17\podTec_C002.2011.091.23.21.0024.G17.00_2013.nc"]

namec4 = ["G17\podTec_C004.2011.091.00.50.0035.G17.00_2013.nc",
"G11\podTec_C002.2011.091.21.39.0019.G11.00_2013.png",
"G11\podTec_C002.2011.091.22.14.0034.G11.01_2013.png",
"G11\podTec_C004.2011.091.01.05.0033.G11.00_2013.png",
"G11\podTec_C004.2011.091.05.09.0026.G11.00_2013.png",
"G11\podTec_C004.2011.091.06.58.0038.G11.00_2013.png",
"G11\podTec_C004.2011.091.11.02.0031.G11.00_2013.png",
"G11\podTec_C004.2011.091.12.47.0016.G11.00_2013.png",
"G11\podTec_C004.2011.091.14.44.0011.G11.00_2013.png",
"G11\podTec_C004.2011.091.16.55.0016.G11.00_2013.png",
"G11\podTec_C004.2011.091.20.43.0010.G11.00_2013.png",
"G11\podTec_C005.2011.091.00.00.0027.G11.01_2013.png",
"G11\podTec_C005.2011.091.01.53.0019.G11.01_2013.png",
"G11\podTec_C005.2011.091.08.02.0019.G11.01_2013.png",
"G11\podTec_C005.2011.091.09.53.0017.G11.01_2013.png",
"G11\podTec_C005.2011.091.10.13.0010.G11.01_2013.png",
"G11\podTec_C005.2011.091.11.37.0039.G11.01_2013.png",
"G11\podTec_C005.2011.091.13.34.0024.G11.01_2013.png",
"G11\podTec_C005.2011.091.19.47.0010.G11.01_2013.png",
"G11\podTec_C005.2011.091.21.33.0022.G11.01_2013.png",
"G11\podTec_C005.2011.091.23.25.0034.G11.01_2013.png",
"G11\podTec_C006.2011.091.00.06.0016.G11.01_2013.png",
"G11\podTec_C006.2011.091.01.43.0019.G11.01_2013.png",
"G11\podTec_C006.2011.091.03.42.0022.G11.01_2013.png",
"G11\podTec_C006.2011.091.04.04.0013.G11.01_2013.png",
"G11\podTec_C006.2011.091.05.43.0031.G11.01_2013.png",
"G11\podTec_C006.2011.091.07.02.0025.G11.00_2013.png",
"G11\podTec_C006.2011.091.07.36.0032.G11.01_2013.png"]

# %%
#绘制podTec每个文件对应的轨迹（TEC对应colormap）

for j in np.arange(67):
    nc1 = Dataset(name[j])
    
    x = nc1.variables['x_GPS']
    y = nc1.variables['y_GPS']
    z = nc1.variables['z_GPS']
    xl = nc1.variables['x_LEO']
    yl = nc1.variables['y_LEO']
    zl = nc1.variables['z_LEO']
    tec = nc1.variables['TEC']
    
    idex = int(x.size) #-1
    
    lo = np.empty(idex)
    la = np.empty(idex)
    al = np.empty(idex)
    lol = np.empty(idex)
    lal = np.empty(idex)
    all = np.empty(idex)
    lot = np.empty(idex)
    lat = np.empty(idex)
    alt = np.empty(idex)
    t = np.empty(idex)
    
    
    for i in np.arange(0,idex,1):
        (lal[i],lol[i],all[i]) = ecf2lla(xl[i],yl[i],zl[i])
        (la[i],lo[i],al[i]) = ecf2lla(x[i],y[i],z[i])
        lat[i] = (lal[i]+la[i])/2 
        lot[i] = (lol[i]+lo[i])/2 
        alt[i] = (all[i]+al[i])/2 
        t[i] = tec[i]
    
    fig = plt.figure(0)
    plt.scatter(lo,la,color='r',marker='.',linewidths=0.1)
    plt.scatter(lol,lal,color='y',marker='.',linewidths=0.1)
    plt.scatter(lot,lat,c=t, cmap=plt.cm.jet,s=20,marker='.',linewidths=0.1)
    plt.xlim(-100 ,100 )
    plt.ylim(-80 ,80 )
    plt.colorbar()
    plt.xlabel('经度/Longitude ($\circ$)')
    plt.ylabel('纬度/Latitude($\circ$)')
    plt.grid(True)
    plt.savefig(name_pic[j], format='png', transparent=True, dpi=400, pad_inches = 0)
    plt. close(0)

# %%
#绘制GPS和LEO对应轨迹

plt.figure(figsize=(24,18))

for j in np.arange(len(name[0])):
    nc1 = Dataset(name[0][j])
    
    x = nc1.variables['x_GPS']
    y = nc1.variables['y_GPS']
    z = nc1.variables['z_GPS']
    xl = nc1.variables['x_LEO']
    yl = nc1.variables['y_LEO']
    zl = nc1.variables['z_LEO']
    tec = nc1.variables['TEC']
    
    idex = int(x.size) #-1
    
    lo = np.empty(idex)
    la = np.empty(idex)
    al = np.empty(idex)
    lol = np.empty(idex)
    lal = np.empty(idex)
    all = np.empty(idex)
    lot = np.empty(idex)
    lat = np.empty(idex)
    alt = np.empty(idex)
    t = np.empty(idex)
    
    
    for i in np.arange(0,idex,1):
        (lal[i],lol[i],all[i]) = ecf2lla(xl[i],yl[i],zl[i])
        (la[i],lo[i],al[i]) = ecf2lla(x[i],y[i],z[i])
        lat[i] = (lal[i]+la[i])/2 
        lot[i] = (lol[i]+lo[i])/2 
        alt[i] = (all[i]+al[i])/2 
        t[i] = tec[i]
    
    
    
    plt.scatter(lo,la,color='r',marker='.',linewidths=0.01)
    plt.scatter(lol,lal,color='b',marker='.',linewidths=0.01)
    #plt.scatter(lot,lat,c=t, cmap=plt.cm.jet,s=20,marker='.',linewidths=0.1)
    
for j in np.arange(len(name[1])):
    nc1 = Dataset(name[1][j])
    
    x = nc1.variables['x_GPS']
    y = nc1.variables['y_GPS']
    z = nc1.variables['z_GPS']
    xl = nc1.variables['x_LEO']
    yl = nc1.variables['y_LEO']
    zl = nc1.variables['z_LEO']
    tec = nc1.variables['TEC']
    
    idex = int(x.size) #-1
    
    lo = np.empty(idex)
    la = np.empty(idex)
    al = np.empty(idex)
    lol = np.empty(idex)
    lal = np.empty(idex)
    all = np.empty(idex)
    lot = np.empty(idex)
    lat = np.empty(idex)
    alt = np.empty(idex)
    t = np.empty(idex)
    
    
    for i in np.arange(0,idex,1):
        (lal[i],lol[i],all[i]) = ecf2lla(xl[i],yl[i],zl[i])
        (la[i],lo[i],al[i]) = ecf2lla(x[i],y[i],z[i])
        lat[i] = (lal[i]+la[i])/2 
        lot[i] = (lol[i]+lo[i])/2 
        alt[i] = (all[i]+al[i])/2 
        t[i] = tec[i]
    
    
    
    plt.scatter(lo,la,color='r',marker='.',linewidths=0.01)
    plt.scatter(lol,lal,color='y',marker='.',linewidths=0.01)
    
    
    
for j in np.arange(len(name[2])):
    nc1 = Dataset(name[2][j])
    
    x = nc1.variables['x_GPS']
    y = nc1.variables['y_GPS']
    z = nc1.variables['z_GPS']
    xl = nc1.variables['x_LEO']
    yl = nc1.variables['y_LEO']
    zl = nc1.variables['z_LEO']
    tec = nc1.variables['TEC']
    
    idex = int(x.size) #-1
    
    lo = np.empty(idex)
    la = np.empty(idex)
    al = np.empty(idex)
    lol = np.empty(idex)
    lal = np.empty(idex)
    all = np.empty(idex)
    lot = np.empty(idex)
    lat = np.empty(idex)
    alt = np.empty(idex)
    t = np.empty(idex)
    
    
    for i in np.arange(0,idex,1):
        (lal[i],lol[i],all[i]) = ecf2lla(xl[i],yl[i],zl[i])
        (la[i],lo[i],al[i]) = ecf2lla(x[i],y[i],z[i])
        lat[i] = (lal[i]+la[i])/2 
        lot[i] = (lol[i]+lo[i])/2 
        alt[i] = (all[i]+al[i])/2 
        t[i] = tec[i]
    
    
    
    plt.scatter(lo,la,color='r',marker='.',linewidths=0.01)
    plt.scatter(lol,lal,color='g',marker='.',linewidths=0.01)    
    
    
for j in np.arange(len(name[3])):
    nc1 = Dataset(name[3][j])
    
    x = nc1.variables['x_GPS']
    y = nc1.variables['y_GPS']
    z = nc1.variables['z_GPS']
    xl = nc1.variables['x_LEO']
    yl = nc1.variables['y_LEO']
    zl = nc1.variables['z_LEO']
    tec = nc1.variables['TEC']
    
    idex = int(x.size) #-1
    
    lo = np.empty(idex)
    la = np.empty(idex)
    al = np.empty(idex)
    lol = np.empty(idex)
    lal = np.empty(idex)
    all = np.empty(idex)
    lot = np.empty(idex)
    lat = np.empty(idex)
    alt = np.empty(idex)
    t = np.empty(idex)
    
    
    for i in np.arange(0,idex,1):
        (lal[i],lol[i],all[i]) = ecf2lla(xl[i],yl[i],zl[i])
        (la[i],lo[i],al[i]) = ecf2lla(x[i],y[i],z[i])
        lat[i] = (lal[i]+la[i])/2 
        lot[i] = (lol[i]+lo[i])/2 
        alt[i] = (all[i]+al[i])/2 
        t[i] = tec[i]
    
    
    
    plt.scatter(lo,la,color='r',marker='.',linewidths=0.01)
    plt.scatter(lol,lal,color='m',marker='.',linewidths=0.01)    
    
    
for j in np.arange(len(name[4])):
    nc1 = Dataset(name[4][j])
    
    x = nc1.variables['x_GPS']
    y = nc1.variables['y_GPS']
    z = nc1.variables['z_GPS']
    xl = nc1.variables['x_LEO']
    yl = nc1.variables['y_LEO']
    zl = nc1.variables['z_LEO']
    tec = nc1.variables['TEC']
    
    idex = int(x.size) #-1
    
    lo = np.empty(idex)
    la = np.empty(idex)
    al = np.empty(idex)
    lol = np.empty(idex)
    lal = np.empty(idex)
    all = np.empty(idex)
    lot = np.empty(idex)
    lat = np.empty(idex)
    alt = np.empty(idex)
    t = np.empty(idex)
    
    
    for i in np.arange(0,idex,1):
        (lal[i],lol[i],all[i]) = ecf2lla(xl[i],yl[i],zl[i])
        (la[i],lo[i],al[i]) = ecf2lla(x[i],y[i],z[i])
        lat[i] = (lal[i]+la[i])/2 
        lot[i] = (lol[i]+lo[i])/2 
        alt[i] = (all[i]+al[i])/2 
        t[i] = tec[i]
    
    
    
    plt.scatter(lo,la,color='r',marker='.',linewidths=0.01)
    plt.scatter(lol,lal,color='k',marker='.',linewidths=0.01)    
    
    
plt.xlim(-100 ,100 )
"G17\podTec_C004.2011.091.20.23.0040.G17.00_2013.nc",
"G17\podTec_C004.2011.091.22.15.0036.G17.00_2013.nc"),


("G17\podTec_C005.2011.091.00.00.0016.G17.01_2013.nc",
"G17\podTec_C005.2011.091.01.33.0027.G17.01_2013.nc",
"G17\podTec_C005.2011.091.02.00.0009.G17.01_2013.nc",
"G17\podTec_C005.2011.091.03.26.0026.G17.01_2013.nc",
"G17\podTec_C005.2011.091.11.28.0033.G17.01_2013.nc",
"G17\podTec_C005.2011.091.13.21.0024.G17.01_2013.nc",
"G17\podTec_C005.2011.091.15.11.0025.G17.01_2013.nc",
"G17\podTec_C005.2011.091.23.10.0032.G17.01_2013.nc"),


("G17\podTec_C006.2011.091.01.27.0027.G17.01_2013.nc",
"G17\podTec_C006.2011.091.03.29.0027.G17.01_2013.nc",
"G17\podTec_C006.2011.091.04.46.0037.G17.00_2013.nc",
"G17\podTec_C006.2011.091.05.20.0033.G17.01_2013.nc",
"G17\podTec_C006.2011.091.07.23.0028.G17.01_2013.nc",
"G17\podTec_C006.2011.091.08.42.0020.G17.00_2013.nc",
"G17\podTec_C006.2011.091.09.15.0032.G17.01_2013.nc",
"G17\podTec_C006.2011.091.10.38.0024.G17.00_2013.nc",
"G17\podTec_C006.2011.091.11.17.0029.G17.01_2013.nc",
"G17\podTec_C006.2011.091.13.14.0030.G17.01_2013.nc",
"G17\podTec_C006.2011.091.14.39.0012.G17.00_2013.nc",
"G17\podTec_C006.2011.091.15.11.0029.G17.01_2013.nc",
"G17\podTec_C006.2011.091.17.09.0029.G17.01_2013.nc",
"G17\podTec_C006.2011.091.19.07.0028.G17.01_2013.nc",
"G17\podTec_C006.2011.091.21.02.0032.G17.01_2013.nc",
"G17\podTec_C006.2011.091.22.23.0009.G17.00_2013.nc",
"G17\podTec_C006.2011.091.23.03.0028.G17.01_2013.nc")]

# %%
#绘制每个文件tec-elevation关系图

for j in np.arange(67):
    nc1 = Dataset(name[j])
    
    ele = nc1.variables['elevation']
    tec = nc1.variables['TEC']
    
    idex = int(tec.size)
    
    fig = plt.figure(0)
    plt.xlim(-100 ,100 )
    plt.grid(True)
    
    for i in np.arange(0,idex,1):
        plt.scatter(ele[i],tec[i],color='b',marker='.',linewidths=0.1)

    
    plt.savefig(name_tec[j], format='png', transparent=True, dpi=400, pad_inches = 0)
    plt.close(0)

# %%
from mpl_toolkits.basemap import Basemap

# %%
#绘制GPS在地图上的轨迹

plt.figure(figsize=(12,6))

map = Basemap()

map.drawmapboundary(fill_color = 'aqua')
map.fillcontinents(color = 'coral', lake_color = 'aqua')
map.drawcoastlines()

for j in np.arange(67):
    nc1 = Dataset(name[j])
    x = nc1.variables['x_GPS']
    y = nc1.variables['y_GPS']
    z = nc1.variables['z_GPS']
    
    idex = int(x.size) #-1
    
    lo = np.empty(idex)
    la = np.empty(idex)
    al = np.empty(idex)
    
    for i in np.arange(0,idex,1):
        (la[i],lo[i],al[i]) = ecf2lla(x[i],y[i],z[i])
    
    map.plot(lo,la,color = 'b')
